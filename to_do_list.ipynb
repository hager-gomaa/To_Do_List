# %%
tasks=[]

def add_tasks(task):
  tasks.append(task)
  print(f"Task '{task}' added.")

def view_tasks():
  if not tasks :
    print("no tasks in the list")
  else:
    print("your tasks:")
    for i, task in enumerate(tasks,1):
          print(f"{i}. {task}")

def remove_tasks(index):
  if 1<= index <= len(tasks):
    removed= tasks.pop(index-1)
    print(f"task '{removed}' removed.")
  else:
    print("invalid task number")

def main():
  while True:
    print("/n Option 1-ADD TASK 2-VIEW TASK 3-REMOVE TASK 4-QUIT")
    choice= input("CHOOSE AN OPTION (1-4):").strip()

    if choice == '1':
      task= input("ENTER TASK:").strip()
      if task:
        add_tasks(task)
      else:
        print("task cannot be empty")

    elif choice == '2':
      view_tasks()

    elif choice == '3':
        try:
          index = int(input("Enter task number to remove: "))
          remove_tasks(index)
        except ValueError:
          print("Please enter a valid number.")

    elif choice == '4':
      print("GOODBYE!")
      break

    else:
      print("INVALID CHOICE. TRY AGAIN.")

if __name__ == "__main__":
  main()
# Out:
# /n Option 1-ADD TASK 2-VIEW TASK 3-REMOVE TASK 4-QUIT
# CHOOSE AN OPTION (1-4):1
# ENTER TASK:first task
# Task 'first task' added.
# /n Option 1-ADD TASK 2-VIEW TASK 3-REMOVE TASK 4-QUIT
# CHOOSE AN OPTION (1-4):2
# your tasks:
# 1. first task
# /n Option 1-ADD TASK 2-VIEW TASK 3-REMOVE TASK 4-QUIT
# CHOOSE AN OPTION (1-4):1
# ENTER TASK:upload
# Task 'upload' added.
# /n Option 1-ADD TASK 2-VIEW TASK 3-REMOVE TASK 4-QUIT
# CHOOSE AN OPTION (1-4):3
# Enter task number to remove: 2
# task 'upload' removed.
# /n Option 1-ADD TASK 2-VIEW TASK 3-REMOVE TASK 4-QUIT
# CHOOSE AN OPTION (1-4):2
# your tasks:
# 1. first task
# /n Option 1-ADD TASK 2-VIEW TASK 3-REMOVE TASK 4-QUIT
# CHOOSE AN OPTION (1-4):4
# GOODBYE!
